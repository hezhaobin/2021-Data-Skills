# %%
age = 42
first_name = "Ahmed"

# %%
print(first_name, 'is', age, 'years old')
# Out:
# Ahmed is 42 years old

# %%
print(last_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a637c5453549> in <module>
# ----> 1 print(last_name)
#
# NameError: name 'last_name' is not defined

# %%
print(myval)
# Out:
# 1

# %%
myval = 1

# %%
age = age + 3
print('Age in three years:', age)
# Out:
# Age in three years: 45

# %%
atom_name = 'helium'
print(atom_name[0])
# Out:
# h

# %%
atom_name = 'sodium'
print(atom_name[0:3])
# Out:
# sod

# %%
print(len('helium'))
# Out:
# 6

# %%
flabadab = 42
ewr_422_yY = 'Ahmed'
print(ewr_422_yY, 'is', flabadab, 'years old')
# Out:
# Ahmed is 42 years old

# %%
initial = 'left'
position = initial
initial = 'right'

# %%
a = 123
print(a[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-c761901e9428> in <module>
#       1 a = 123
# ----> 2 print(a[1])
#
# TypeError: 'int' object is not subscriptable
